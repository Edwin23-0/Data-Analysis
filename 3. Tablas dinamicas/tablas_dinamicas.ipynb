# %% [markdown]
# ## Uso de tabla dinamicas - Dataset Banco

# %% [markdown]
# En este notebook comenzaremos a trabajar con tablas dinámicas en Excel. Aprenderemos qué son, para qué sirven, cómo se utilizan y cómo crearlas para analizar cualquier dataset. Además, exploraremos diferentes ejemplos prácticos que permitirán resumir, organizar y visualizar información de manera eficiente.
