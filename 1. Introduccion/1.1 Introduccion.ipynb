# %% [markdown]
# ## Aprendizaje Data Analyst

# %% [markdown]
# Este notebook se configurará desde cero el entorno de trabajo necesario para las prácticas de análisis de datos: entorno virtual, dependencias, Jupyter Notebook y kernel de Python.

# %% [markdown]
#  ## Herramientas utilizadas

# %% [markdown]
# - Python
# - Jupyter Notebook
# - pandas
# - numpy
# - matplotlib
# - seaborn
# - openpyxl

# %% [markdown]
# ## Instalación de Python

# %% [markdown]
# - Se descargó Python desde la página oficial: https://www.python.org/downloads/
# - Se instaló seleccionando la opción **Add Python to PATH**
# - Se verificó la instalación usando el comando:

# %%
python --version

# %% [markdown]
# ## Instalación extensión para VS Code

# %% [markdown]
# Se instalaron extensiones:
#
# - Python
# - Jupyter

# %% [markdown]
# ## Instalación de librerías

# %%
python -m pip install pandas numpy matplotlib seaborn openpyxl jupyter
